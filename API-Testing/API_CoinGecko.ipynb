# %% [markdown]
# # API CoinGecko
#
# https://www.coingecko.com/api/documentations/v3#/
#
# Base URL: https://api.coingecko.com/api/v3

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install datetime
# Out:
# Collecting datetime
#   Using cached DateTime-4.3-py2.py3-none-any.whl (60 kB)
# Requirement already satisfied: pytz in c:\users\daveb\anaconda3\lib\site-packages (from datetime) (2020.1)
# Requirement already satisfied: zope.interface in c:\users\daveb\anaconda3\lib\site-packages (from datetime) (4.7.1)
# Requirement already satisfied: setuptools in c:\users\daveb\anaconda3\lib\site-packages (from zope.interface->datetime) (49.2.0.post20200714)
# Installing collected packages: datetime
# Successfully installed datetime-4.3

# %%
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# #### Historical Market Data (Number of Days)
# Get historical market data include price, market cap, and 24h volume (granularity auto) for a **specific coin**.
#
# Minutely data will be used for duration within 1 day, Hourly data will be used for duration between 1 day and 90 days, Daily data will be used for duration above 90 days.

# %% [markdown]
# **Get historical data of specific coins and write data in a data frame**

# %%
coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "spell-token", "dopex" , "gro-dao-token", "audius", "ecomi", "raydium"]

column_names = ["prices", "market_caps", "total_volumes", "coin"]
df_coin_historical_data = pd.DataFrame(columns=column_names)

for coin in coins:
    url = 'https://api.coingecko.com/api/v3/coins/' + coin + '/market_chart?vs_currency=usd&days=100'
    r = requests.get(url)
    r.json()
    df_coin = pd.DataFrame(r.json())    
    df_coin["coin"] = coin
    df_coin_historical_data = df_coin_historical_data.append(df_coin, ignore_index=True)


print(df_coin_historical_data)
# Out:
#                                    prices  \
# 0     [1626998400000, 3.2387703037262776]
# 1     [1627084800000, 3.8550975503932903]
# 2     [1627171200000, 3.9684750140035607]
# 3     [1627257600000, 3.6098913997339084]
# 4     [1627344000000, 3.4735455601944683]
# ...                                   ...
# 1010  [1635292800000, 10.325751656462332]
# 1011   [1635379200000, 9.334652900668676]
# 1012   [1635465600000, 9.978156902613437]
# 1013  [1635552000000, 10.408176394593982]
# 1014   [1635584837000, 10.42472730638147]
#
#                               market_caps  \
# 0      [1626998400000, 41688195.48411817]
# 1     [1627084800000, 50856326.292116106]
# 2      [1627171200000, 53274811.48689771]
# 3      [1627257600000, 48921820.52789484]
# 4      [1627344000000, 48390706.74572702]
# ...                                   ...
# 1010   [1635292800000, 769776376.6960338]
# 1011   [1635379200000, 695699116.5946562]
# 1012   [1635465600000, 732682930.8747901]
# 1013    [1635552000000, 769048915.144684]
# 1014   [1635584837000, 771226846.8941249]
#
#                             total_volumes            coin
# 0         [1626998400000, 8461820.693273]  convex-finance
# 1       [1627084800000, 8010349.60493514]  convex-finance
# 2     [1627171200000, 3467171.4856020734]  convex-finance
# 3     [1627257600000, 2214928.8856311734]  convex-finance
# 4      [1627344000000, 3642922.748519657]  convex-finance
# ...                                   ...             ...
# 1010  [1635292800000, 110729801.36426839]         raydium
# 1011  [1635379200000, 184602311.28186256]         raydium
# 1012  [1635465600000, 168585277.90080944]         raydium
# 1013   [1635552000000, 153868899.1173795]         raydium
# 1014  [1635584837000, 121643469.41789462]         raydium
#
# [1015 rows x 4 columns]

# %%
coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "spell-token", "dopex" , "gro-dao-token", "audius", "ecomi", "raydium"]

column_names = ["prices", "market_caps", "total_volumes", "coin"]
df_coin_historical_data = pd.DataFrame(columns=column_names)

for coin in coins:
    url = 'https://api.coingecko.com/api/v3/coins/' + coin + '/market_chart?vs_currency=usd&days=100'
    r = requests.get(url)
    r.json()
    df_coin = pd.DataFrame(r.json())    
    df_coin["coin"] = coin
    df_coin_historical_data = df_coin_historical_data.append(df_coin, ignore_index=True)



for i, value in df_coin_historical_data.iterrows():
    df_coin_historical_data.loc[i, "date"] = datetime.utcfromtimestamp(df_coin_historical_data.loc[i,"prices"][0]/1000).strftime('%Y-%m-%d %H:%M:%S')
    df_coin_historical_data.loc[i, "prices"] = df_coin_historical_data.loc[i,"prices"][1]
    df_coin_historical_data.loc[i, "market_caps"] = df_coin_historical_data.loc[i,"market_caps"][1]
    df_coin_historical_data.loc[i, "total_volumes"] = df_coin_historical_data.loc[i,"total_volumes"][1]

    #print(datetime.utcfromtimestamp(df_coin_historical_data.loc[i,"prices"][0]/1000).strftime('%Y-%m-%d %H:%M:%S'))
   # print(i, value["prices"])

print(df_coin_historical_data)
# Out:
#       prices  market_caps total_volumes            coin                 date
# 0    2.57168  2.82378e+07   1.31211e+06  convex-finance  2021-07-14 00:00:00
# 1    2.54807  2.84486e+07        885286  convex-finance  2021-07-15 00:00:00
# 2    2.26806  2.57982e+07   2.06394e+06  convex-finance  2021-07-16 00:00:00
# 3    2.09515  2.41792e+07   1.83386e+06  convex-finance  2021-07-17 00:00:00
# 4     2.5936  3.04126e+07   3.03133e+06  convex-finance  2021-07-18 00:00:00
# ..       ...          ...           ...             ...                  ...
# 983  9.56957  6.92508e+08   7.27969e+07         raydium  2021-10-18 00:00:00
# 984  9.32187  6.73219e+08   6.50291e+07         raydium  2021-10-19 00:00:00
# 985  9.47495  6.84563e+08    5.2298e+07         raydium  2021-10-20 00:00:00
# 986  10.3039  7.45651e+08   9.98731e+07         raydium  2021-10-21 00:00:00
# 987  10.5752  7.61637e+08   1.82578e+08         raydium  2021-10-21 08:42:33
#
# [988 rows x 5 columns]

# %%
coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "spell-token", "dopex" , "gro-dao-token", "audius", "ecomi", "raydium"]

column_names = ["prices", "market_caps", "total_volumes", "coin"]
df_coin_historical_data = pd.DataFrame(columns=column_names)

for coin in coins:
    url = 'https://api.coingecko.com/api/v3/coins/' + coin + '/market_chart?vs_currency=usd&days=90'
    r = requests.get(url)
    r.json()
    df_coin = pd.DataFrame(r.json())    
    df_coin["coin"] = coin
    df_coin_historical_data = df_coin_historical_data.append(df_coin, ignore_index=True)


for i, value in df_coin_historical_data.iterrows():
    df_coin_historical_data.loc[i, "date"] = datetime.utcfromtimestamp(df_coin_historical_data.loc[i,"prices"][0]/1000).strftime('%Y-%m-%d %H:%M:%S')
    df_coin_historical_data.loc[i, "date_unix"] = df_coin_historical_data.loc[i,"prices"][0]
    df_coin_historical_data.loc[i, "prices"] = df_coin_historical_data.loc[i,"prices"][1]
    df_coin_historical_data.loc[i, "market_caps"] = df_coin_historical_data.loc[i,"market_caps"][1]
    df_coin_historical_data.loc[i, "total_volumes"] = df_coin_historical_data.loc[i,"total_volumes"][1]

    #print(datetime.utcfromtimestamp(df_coin_historical_data.loc[i,"prices"][0]/1000).strftime('%Y-%m-%d %H:%M:%S'))
   # print(i, value["prices"])

print(df_coin_historical_data)
# Out:
#         prices  market_caps total_volumes            coin  \
# 0      3.44908  5.17546e+07   2.17102e+06  convex-finance
# 1      3.42441  5.16721e+07   2.14435e+06  convex-finance
# 2      3.42757  5.15093e+07   2.14184e+06  convex-finance
# 3       3.4373  5.16904e+07   2.22524e+06  convex-finance
# 4      3.41576  5.14049e+07   2.17096e+06  convex-finance
# ...        ...          ...           ...             ...
# 21427  10.2835  7.57083e+08    1.3451e+08         raydium
# 21428  10.3619  7.60525e+08   1.30515e+08         raydium
# 21429  10.3952  7.68774e+08   1.26993e+08         raydium
# 21430  10.5096  7.74455e+08   1.24916e+08         raydium
# 21431  10.4296  7.74421e+08   1.22035e+08         raydium
#
#                       date     date_unix
# 0      2021-08-01 10:03:13  1.627812e+12
# 1      2021-08-01 11:01:46  1.627816e+12
# 2      2021-08-01 12:02:25  1.627819e+12
# 3      2021-08-01 13:02:21  1.627823e+12
# 4      2021-08-01 14:01:29  1.627826e+12
# ...                    ...           ...
# 21427  2021-10-30 05:22:24  1.635571e+12
# 21428  2021-10-30 06:22:32  1.635575e+12
# 21429  2021-10-30 07:22:16  1.635579e+12
# 21430  2021-10-30 08:22:16  1.635582e+12
# 21431  2021-10-30 09:01:34  1.635584e+12
#
# [21432 rows x 6 columns]

# %% [markdown]
# **Get daily data (at 00:00:00)**

# %%
coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "spell-token", "dopex" , "gro-dao-token", "audius", "ecomi", "raydium"]

column_names = ["prices", "market_caps", "total_volumes", "coin"]
df_coin_historical_data = pd.DataFrame(columns=column_names)

for coin in coins:
    url = 'https://api.coingecko.com/api/v3/coins/' + coin + '/market_chart?vs_currency=usd&days=1&interval=daily'
    r = requests.get(url)
    r.json()
    df_coin = pd.DataFrame(r.json())    
    df_coin["coin"] = coin
    df_coin_historical_data = df_coin_historical_data.append(df_coin, ignore_index=True)


for i, value in df_coin_historical_data.iterrows():
    df_coin_historical_data.loc[i, "date"] = datetime.utcfromtimestamp(df_coin_historical_data.loc[i,"prices"][0]/1000).strftime('%Y-%m-%d %H:%M:%S')
    df_coin_historical_data.loc[i, "date_unix"] = df_coin_historical_data.loc[i,"prices"][0]
    df_coin_historical_data.loc[i, "prices"] = df_coin_historical_data.loc[i,"prices"][1]
    df_coin_historical_data.loc[i, "market_caps"] = df_coin_historical_data.loc[i,"market_caps"][1]
    df_coin_historical_data.loc[i, "total_volumes"] = df_coin_historical_data.loc[i,"total_volumes"][1]

    #print(datetime.utcfromtimestamp(df_coin_historical_data.loc[i,"prices"][0]/1000).strftime('%Y-%m-%d %H:%M:%S'))
   # print(i, value["prices"])

print(df_coin_historical_data)
# Out:
#         prices  market_caps total_volumes                   coin  \
# 0      31.9596  1.06705e+09   3.76888e+07         convex-finance
# 1      32.4887  1.09165e+09   3.00421e+07         convex-finance
# 2      1.90815  7.12311e+07   2.30094e+07         ribbon-finance
# 3      1.81024  6.72242e+07   1.82625e+07         ribbon-finance
# 4      42.5653  4.78934e+08   7.73196e+06  rari-governance-token
# 5      41.1466  4.62387e+08   2.92625e+06  rari-governance-token
# 6      39.1813  2.64186e+08   2.17828e+06                    gmx
# 7      37.7266  2.53922e+08    2.1894e+06                    gmx
# 8      147.256  6.18946e+07        489536                   nftx
# 9      143.594  6.02531e+07        335184                   nftx
# 10     61.2642     7.35e+09   2.37026e+08              ftx-token
# 11     60.6316  7.28096e+09   2.07672e+08              ftx-token
# 12    0.023597  1.71421e+09   4.16474e+07            spell-token
# 13   0.0229817  1.68146e+09   3.70966e+07            spell-token
# 14     2152.97  3.17026e+08   6.55548e+06                  dopex
# 15     2172.92   3.1926e+08   6.75397e+06                  dopex
# 16     17.5697  5.82466e+07   8.42351e+06          gro-dao-token
# 17     17.2416  5.47315e+07   4.88493e+06          gro-dao-token
# 18     2.04844  8.46223e+08   1.94728e+07                 audius
# 19     1.98646  8.15425e+08   1.89676e+07                 audius
# 20  0.00662157  1.44563e+09   9.47701e+06                  ecomi
# 21  0.00628355  1.36712e+09   7.79442e+06                  ecomi
# 22     10.4082  7.69049e+08   1.53869e+08                raydium
# 23     10.4286  7.71227e+08   1.21475e+08                raydium
#
#                    date     date_unix
# 0   2021-10-30 00:00:00  1.635552e+12
# 1   2021-10-30 09:07:22  1.635585e+12
# 2   2021-10-30 00:00:00  1.635552e+12
# 3   2021-10-30 09:07:49  1.635585e+12
# 4   2021-10-30 00:00:00  1.635552e+12
# 5   2021-10-30 09:07:54  1.635585e+12
# 6   2021-10-30 00:00:00  1.635552e+12
# 7   2021-10-30 09:03:25  1.635585e+12
# 8   2021-10-30 00:00:00  1.635552e+12
# 9   2021-10-30 09:07:55  1.635585e+12
# 10  2021-10-30 00:00:00  1.635552e+12
# 11  2021-10-30 09:07:19  1.635585e+12
# 12  2021-10-30 00:00:00  1.635552e+12
# 13  2021-10-30 09:07:26  1.635585e+12
# 14  2021-10-30 00:00:00  1.635552e+12
# 15  2021-10-30 09:08:14  1.635585e+12
# 16  2021-10-30 00:00:00  1.635552e+12
# 17  2021-10-30 09:03:10  1.635585e+12
# 18  2021-10-30 00:00:00  1.635552e+12
# 19  2021-10-30 09:07:41  1.635585e+12
# 20  2021-10-30 00:00:00  1.635552e+12
# 21  2021-10-30 09:08:08  1.635585e+12
# 22  2021-10-30 00:00:00  1.635552e+12
# 23  2021-10-30 09:08:33  1.635585e+12

# %% [markdown]
# **Get current data**

# %%
import numpy as np
import pandas as pd

coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "audius", "ecomi", "spell-token", "dopex" , "gro-dao-token",  "raydium"]

column_names = ["prices (usd)", "market_caps", "total_volumes", "coin", "date"]
df_coin_current_data = pd.DataFrame(columns=column_names)

url = 'https://api.coingecko.com/api/v3/coins/convex-finance'
r = requests.get(url)
#df = pd.DataFrame.from_dict(r.json().get("market_data")).loc["usd"]
df = pd.DataFrame.from_dict(r.json().get("market_data"))
df = df.rename_axis('currency').reset_index()
print(df[df['currency'] == 'usd'])
# Out:
#    currency  current_price  total_value_locked  mcap_to_tvl_ratio  \
# 48      usd          28.91        1.384839e+10               0.07
#
#     fdv_to_tvl_ratio   roi    ath  ath_change_percentage  \
# 48              0.21  None  33.04              -12.63308
#
#                     ath_date  atl  ...  \
# 48  2021-10-29T20:18:36.714Z  1.9  ...
#
#     price_change_percentage_30d_in_currency  \
# 48                                 235.4505
#
#    price_change_percentage_60d_in_currency  \
# 48                               364.97688
#
#     price_change_percentage_200d_in_currency  \
# 48                                       NaN
#
#     price_change_percentage_1y_in_currency  market_cap_change_24h_in_currency  \
# 48                                     NaN                      -1.222967e+08
#
#     market_cap_change_percentage_24h_in_currency  total_supply   max_supply  \
# 48                                     -11.22177  7.272534e+07  100000000.0
#
#     circulating_supply              last_updated
# 48        3.349561e+07  2021-10-30T16:19:16.385Z
#
# [1 rows x 43 columns]

# %%
import requests
import numpy as np
import pandas as pd

coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "audius", "ecomi", "spell-token", "dopex" , "gro-dao-token",  "raydium"]

df_coin_current_data = pd.DataFrame()


for coin in coins: 
    url = 'https://api.coingecko.com/api/v3/coins/' + coin
    r = requests.get(url)
    df = pd.DataFrame.from_dict(r.json().get("market_data"))
    df = df.rename_axis('currency').reset_index()
    df = df[df['currency'] == 'usd']
    df_coin_current_data = df_coin_current_data.append(df)

print(df_coin_current_data)
# Out:
#    currency  current_price total_value_locked mcap_to_tvl_ratio  \
# 48      usd      28.910000        1.38484e+10              0.07
# 48      usd       1.780000               None              None
# 48      usd      40.740000        1.04735e+09              0.44
# 48      usd      36.950000         7.5617e+07              3.29
# 48      usd     142.690000        5.94338e+07              1.01
# 48      usd      59.960000               None              None
# 48      usd       2.150000               None              None
# 48      usd       0.006290               None              None
# 48      usd       0.022208        3.96597e+09              0.41
# 48      usd    2042.770000                  0              None
# 48      usd      16.500000        4.35227e+07               1.2
# 48      usd      10.600000        1.81458e+09              0.43
#
#    fdv_to_tvl_ratio   roi          ath  ath_change_percentage  \
# 48             0.21  None    33.040000              -12.63308
# 48             None  None     5.540000              -67.90913
# 48             0.49  None    51.900000              -21.50529
# 48             6.48  None    40.230000               -8.13515
# 48             1.56  None   499.090000              -71.41047
# 48             None  None    84.180000              -28.84834
# 48             None  None     4.950000              -56.91740
# 48             None   NaN     0.013436              -53.07514
# 48             1.18  None     0.026820              -17.19767
# 48                ?  None  2193.270000               -6.86212
# 48            37.86  None    36.370000              -54.63562
# 48             3.23  None    16.830000              -37.08471
#
#                     ath_date        atl  ...  \
# 48  2021-10-29T20:18:36.714Z   1.900000  ...
# 48  2021-10-07T22:30:49.258Z   1.620000  ...
# 48  2021-10-14T15:41:40.482Z   0.213385  ...
# 48  2021-10-29T01:33:17.696Z  11.770000  ...
# 48  2021-02-16T08:51:13.881Z  16.370000  ...
# 48  2021-09-09T16:59:43.151Z   1.150000  ...
# 48  2021-03-27T15:45:35.137Z   0.043737  ...
# 48  2021-03-19T17:20:53.999Z   0.000003  ...
# 48  2021-10-25T13:35:23.932Z   0.000298  ...
# 48  2021-10-30T06:53:40.392Z  88.040000  ...
# 48  2021-10-12T04:58:14.614Z   4.600000  ...
# 48  2021-09-12T20:20:23.998Z   2.460000  ...
#
#     price_change_percentage_30d_in_currency  \
# 48                                235.45050
# 48                                      NaN
# 48                                104.92505
# 48                                143.29781
# 48                                 12.54191
# 48                                 20.05440
# 48                                  9.26752
# 48                                 23.20832
# 48                                575.84195
# 48                                107.42089
# 48                                200.90403
# 48                                 15.65155
#
#    price_change_percentage_60d_in_currency  \
# 48                               364.97688
# 48                                     NaN
# 48                               320.99351
# 48                                     NaN
# 48                               -34.15056
# 48                                29.16648
# 48                               -15.21287
# 48                               100.40386
# 48                              1859.04559
# 48                               550.55251
# 48                                     NaN
# 48                                -7.63615
#
#     price_change_percentage_200d_in_currency  \
# 48                                       NaN
# 48                                       NaN
# 48                                 150.45683
# 48                                       NaN
# 48                                  -7.62998
# 48                                  13.45861
# 48                                 -18.35247
# 48                                 -20.68317
# 48                                       NaN
# 48                                       NaN
# 48                                       NaN
# 48                                  -6.68398
#
#     price_change_percentage_1y_in_currency  market_cap_change_24h_in_currency  \
# 48                                     NaN                      -1.214852e+08
# 48                                     NaN                      -4.368438e+06
# 48                             12903.23744                      -8.060240e+06
# 48                                     NaN                      -1.528852e+07
# 48                                     NaN                      -3.559915e+06
# 48                              1456.06503                      -2.167602e+08
# 48                              2049.42241                       8.035849e+06
# 48                             17510.41213                      -1.375180e+08
# 48                                     NaN                      -2.381238e+08
# 48                                     NaN                       1.711628e+07
# 48                                     NaN                       2.508606e+06
# 48                                     NaN                       6.069811e+06
#
#     market_cap_change_percentage_24h_in_currency  total_supply   max_supply  \
# 48                                     -11.14730  7.272534e+07        1e+08
# 48                                      -6.18707  1.000000e+09        1e+09
# 48                                      -1.72727  1.250000e+07     1.25e+07
# 48                                      -5.79087  6.730683e+06    1.325e+07
# 48                                      -5.60714  6.500000e+05       650000
# 48                                      -2.92526  3.360192e+08  3.36019e+08
# 48                                       0.93172  1.057693e+09  1.05769e+09
# 48                                      -9.10751  7.500000e+11         None
# 48                                     -12.87965  1.032149e+11      2.1e+11
# 48                                       6.03319  5.000000e+05         None
# 48                                       5.03772  5.003763e+06        1e+08
# 48                                       0.78246  5.550000e+08     5.55e+08
#
#     circulating_supply              last_updated
# 48        3.349561e+07  2021-10-30T16:19:16.385Z
# 48        3.723773e+07  2021-10-30T16:19:33.861Z
# 48        1.125510e+07  2021-10-30T16:22:19.074Z
# 48        6.730683e+06  2021-10-30T16:18:04.253Z
# 48        4.200000e+05  2021-10-30T16:19:36.371Z
# 48        1.201488e+08  2021-10-30T16:23:42.453Z
# 48        4.119109e+08  2021-10-30T16:24:25.766Z
# 48        2.176827e+11  2021-10-30T16:22:10.448Z
# 48        7.256583e+10  2021-10-30T16:23:27.720Z
# 48        1.472601e+05  2021-10-30T16:14:13.835Z
# 48        3.174394e+06  2021-10-30T16:21:58.286Z
# 48        7.394115e+07  2021-10-30T16:23:56.997Z
#
# [12 rows x 43 columns]

# %%
import numpy as np
import pandas as pd

coins = ["convex-finance", "ribbon-finance", "rari-governance-token", "gmx", "nftx", "ftx-token", "audius", "ecomi", "spell-token", "dopex" , "gro-dao-token",  "raydium"]

column_names = ["prices (usd)", "market_caps", "total_volumes", "coin", "date"]
df_coin_current_data = pd.DataFrame(columns=column_names)

for coin in coins: 
    url = 'https://api.coingecko.com/api/v3/coins/' + coin
    r = requests.get(url)
    coin_market_data = r.json().get("market_data")   
    df2 = pd.DataFrame(np.array([[coin_market_data["current_price"]["usd"],
       coin_market_data["market_cap"]["usd"],
       coin_market_data["total_volume"]["usd"],
       r.json().get("id"), 
       datetime.now()]]), columns=column_names)
    df_coin_current_data = df_coin_current_data.append(df2, ignore_index=True) 

print(df_coin_current_data)

df_coin_current_data.head(8)
# Out:
#    prices (usd) market_caps total_volumes                   coin  \
# 0          28.9   972093831      24443746         convex-finance
# 1          1.78    66289591      11894991         ribbon-finance
# 2         40.81   457218922       2287638  rari-governance-token
# 3         36.97   248817810       1379289                    gmx
# 4         146.3    59555464        443306                   nftx
# 5         59.82  7195110031     209348737              ftx-token
# 6          2.04   828313964      20932085                 audius
# 7    0.00647206  1402138547       8639398                  ecomi
# 8     0.0222097  1603889874      39735154            spell-token
# 9       2080.28   313871620       5243676                  dopex
# 10        16.48    53714821       4227131          gro-dao-token
# 11        10.46   767740929     125490439                raydium
#
#                          date
# 0  2021-10-30 17:47:18.987920
# 1  2021-10-30 17:47:19.441777
# 2  2021-10-30 17:47:20.155473
# 3  2021-10-30 17:47:20.496854
# 4  2021-10-30 17:47:21.558836
# 5  2021-10-30 17:47:22.068053
# 6  2021-10-30 17:47:22.486900
# 7  2021-10-30 17:47:22.739214
# 8  2021-10-30 17:47:23.086287
# 9  2021-10-30 17:47:23.378338
# 10 2021-10-30 17:47:23.703987
# 11 2021-10-30 17:47:24.152023
#   prices (usd) market_caps total_volumes                   coin  \
# 0         28.9   972093831      24443746         convex-finance
# 1         1.78    66289591      11894991         ribbon-finance
# 2        40.81   457218922       2287638  rari-governance-token
# 3        36.97   248817810       1379289                    gmx
# 4        146.3    59555464        443306                   nftx
# 5        59.82  7195110031     209348737              ftx-token
# 6         2.04   828313964      20932085                 audius
# 7   0.00647206  1402138547       8639398                  ecomi
#
#                         date
# 0 2021-10-30 17:47:18.987920
# 1 2021-10-30 17:47:19.441777
# 2 2021-10-30 17:47:20.155473
# 3 2021-10-30 17:47:20.496854
# 4 2021-10-30 17:47:21.558836
# 5 2021-10-30 17:47:22.068053
# 6 2021-10-30 17:47:22.486900
# 7 2021-10-30 17:47:22.739214

# %%
## Converting UNIX Timestampt to readable datetime

from datetime import datetime
ts = int("1633729679000")
ts /= 1000
# if you encounter a "year is out of range" error the timestamp
# may be in milliseconds, try `ts /= 1000` in that case
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2021-10-08 21:47:59

# %%
## Converting UNIX Timestampt to readable datetime

from datetime import datetime
ts = int("33495612")

# if you encounter a "year is out of range" error the timestamp
# may be in milliseconds, try `ts /= 1000` in that case
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 1971-01-23 16:20:12

# %%
import time
int(time.time())
# Out:
# 1635608952

# %% [markdown]
# #### Historical Market Data (Daterange)
# Get historical market data include price, market cap, and 24h volume within a range of timestamp (granularity auto) for a **specific coin**.
#
# * Data granularity is automatic (cannot be adjusted)
# * 1 day from query time = 5 minute interval data
# * 1 - 90 days from query time = hourly data
# * above 90 days from query time = daily data (00:00 UTC)
#
# Parmeter *from* and *to* have to be in UNIX Timestamp

# %%
import datetime
import time
from_date = datetime.datetime(2020, 1, 1) 
from_date = int((time.mktime(from_date.timetuple())))
print()
print("Unix Timestamp from: ",from_date)
print()

to_date = datetime.datetime(2021, 10, 9)
to_date = int((time.mktime(to_date.timetuple())))
print("Unix Timestamp to: ",to_date)
print()
# Out:
# Unix Timestamp from:  1577833200
#
# Unix Timestamp to:  1633730400

# %%
## get daily data from 01.01.2020 till 09.10.2021 (Coin: bitcoin; and price in usd)

url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1577833200&to=1633730400'
r = requests.get(url)
r.json()
pd.DataFrame(r.json())
# Out:
#                                   prices                          market_caps  \
# 0     [1577836800000, 7195.153895430029]  [1577836800000, 130394101535.60994]
# 1       [1577923200000, 7193.7546679601]    [1577923200000, 130422953817.668]
# 2     [1578009600000, 6963.853353983485]  [1578009600000, 126280790200.20206]
# 3      [1578096000000, 7300.34693530511]  [1578096000000, 132766262579.09486]
# 4     [1578182400000, 7351.377053166627]  [1578182400000, 133474716218.18333]
# ..                                   ...                                  ...
# 642   [1633305600000, 48282.97113857447]   [1633305600000, 910331395887.4816]
# 643  [1633392000000, 49260.232321130694]   [1633392000000, 927812140868.0522]
# 644   [1633478400000, 51668.99422435564]   [1633478400000, 973040988102.9114]
# 645   [1633564800000, 55415.00574202895]  [1633564800000, 1044675252844.3663]
# 646   [1633651200000, 53894.59599452107]   [1633651200000, 1015246512238.866]
#
#                            total_volumes
# 0     [1577836800000, 21187883711.18498]
# 1      [1577923200000, 18123516838.8979]
# 2     [1578009600000, 20313194628.09452]
# 3     [1578096000000, 31015776262.21867]
# 4     [1578182400000, 20611640058.34164]
# ..                                   ...
# 642  [1633305600000, 26034594561.963406]
# 643  [1633392000000, 32691763060.319107]
# 644   [1633478400000, 35480330025.02791]
# 645   [1633564800000, 48462388015.80152]
# 646   [1633651200000, 36549815857.28183]
#
# [647 rows x 3 columns]

# %%
## data of two days --> get hourly data 
## Coin: bitcoin; and price in usd

url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1633557600&to=1633730400'
r = requests.get(url)
r.json()
pd.DataFrame(r.json())
# Out:
#                                  prices                          market_caps  \
# 0   [1633557862816, 55206.432439507305]  [1633557862816, 1039907337171.8619]
# 1    [1633561366680, 55292.02506597411]  [1633561366680, 1041520283816.6857]
# 2    [1633565130090, 55348.36545619193]  [1633565130090, 1043970275544.5244]
# 3    [1633568620147, 55010.85173840232]  [1633568620147, 1036227366819.7538]
# 4    [1633572235606, 55161.14293098703]  [1633572235606, 1039218839146.2529]
# 5    [1633575805550, 55148.01458496704]   [1633575805550, 1038815209422.924]
# 6    [1633579730258, 54999.43157934825]  [1633579730258, 1036546529106.7444]
# 7     [1633582882963, 55198.9578428457]  [1633582882963, 1039778242571.1414]
# 8    [1633586434267, 54771.89033563298]   [1633586434267, 1032184406106.835]
# 9   [1633590177215, 54579.466093245355]  [1633590177215, 1028517280325.0852]
# 10   [1633590414981, 54575.26808341444]   [1633590414981, 1028112365788.607]
# 11   [1633593826076, 54739.64443785246]  [1633593826076, 1031132379204.8043]
# 12  [1633597377268, 54621.775775731345]  [1633597377268, 1028895443642.4706]
# 13  [1633601304407, 54499.812812991884]  [1633601304407, 1024737426040.1322]
# 14   [1633604506594, 54040.90370561785]  [1633604506594, 1017975258215.6866]
# 15   [1633608201594, 54477.63102483852]  [1633608201594, 1026216809552.1459]
# 16   [1633611843316, 54029.66264626647]  [1633611843316, 1018609906326.4417]
# 17   [1633615417193, 54588.25334207995]  [1633615417193, 1028290828443.9886]
# 18   [1633619072380, 53701.37704643536]  [1633619072380, 1011586264767.9645]
# 19   [1633622684695, 54070.42332727737]  [1633622684695, 1018541109765.4619]
# 20   [1633626124473, 54456.97584372188]  [1633626124473, 1025826094135.2996]
# 21   [1633630200500, 54291.67158987415]  [1633630200500, 1022979242008.5137]
# 22   [1633633357341, 54024.79510261018]  [1633633357341, 1016761430236.9508]
# 23   [1633637245112, 54057.36043695341]  [1633637245112, 1018354030071.1803]
# 24    [1633640840563, 54250.8138194203]   [1633640840563, 1021981953038.596]
# 25   [1633644298001, 54303.04394229736]  [1633644298001, 1022953731097.0513]
# 26   [1633647790408, 54006.70031073745]  [1633647790408, 1016954429414.0453]
# 27   [1633651368321, 53894.59599452107]   [1633651368321, 1015246512238.866]
# 28   [1633654842324, 54318.06695227984]  [1633654842324, 1023470297559.3419]
# 29   [1633658431521, 54337.03592175362]  [1633658431521, 1024377089485.5459]
# 30   [1633662347064, 53906.80949484352]   [1633662347064, 1016825248975.513]
# 31   [1633666068739, 53907.68082803605]   [1633666068739, 1015955812949.801]
# 32   [1633669549221, 53949.88457262023]  [1633669549221, 1017053494536.0785]
# 33  [1633673002188, 54305.175242670724]  [1633673002188, 1022339218368.1306]
# 34   [1633676617829, 54194.72538431304]   [1633676617829, 1021309195568.339]
# 35  [1633680043332, 54858.439050625755]  [1633680043332, 1029951784658.3141]
# 36   [1633683908558, 55954.43265452176]  [1633683908558, 1052903223661.4249]
# 37     [1633687430341, 55404.419955876]  [1633687430341, 1045008278236.9573]
# 38   [1633691052355, 55568.87472394908]  [1633691052355, 1047722957773.2975]
# 39   [1633695106064, 55326.07105743581]  [1633695106064, 1040926488920.4109]
# 40  [1633698248658, 54864.095929229385]  [1633698248658, 1033531210717.2213]
# 41    [1633702380369, 54337.5175196484]  [1633702380369, 1023515981390.9803]
# 42   [1633705448216, 54691.52972934324]    [1633705448216, 1030511713037.96]
# 43   [1633708942005, 54265.42080536691]  [1633708942005, 1022256067038.0623]
# 44  [1633712591998, 54459.040125244115]  [1633712591998, 1025907185522.0867]
# 45   [1633716145132, 54340.76108472249]  [1633716145132, 1023391539171.1516]
# 46   [1633720121633, 54634.88141047918]  [1633720121633, 1029214699151.5629]
# 47   [1633723794138, 54731.34292528844]   [1633723794138, 1028653601006.588]
# 48  [1633727373786, 53957.129698884164]  [1633727373786, 1020675557616.9868]
#
#                           total_volumes
# 0    [1633557862816, 47962975721.49931]
# 1    [1633561366680, 47940390391.90841]
# 2     [1633565130090, 48391941099.7652]
# 3    [1633568620147, 48573855165.52543]
# 4    [1633572235606, 49083918841.53779]
# 5    [1633575805550, 49224765433.64286]
# 6   [1633579730258, 49143807202.548904]
# 7    [1633582882963, 49267471795.50696]
# 8   [1633586434267, 47098833319.764984]
# 9   [1633590177215, 48521054116.246155]
# 10     [1633590414981, 48474753993.425]
# 11    [1633593826076, 48924886620.3438]
# 12   [1633597377268, 47484524572.47754]
# 13   [1633601304407, 47244266168.99344]
# 14   [1633604506594, 46326986169.45212]
# 15  [1633608201594, 46573425001.275856]
# 16   [1633611843316, 45113023191.35292]
# 17  [1633615417193, 40396813804.059006]
# 18   [1633619072380, 39373804710.13591]
# 19   [1633622684695, 39077210674.93663]
# 20   [1633626124473, 38644377159.42139]
# 21  [1633630200500, 38462890833.756355]
# 22  [1633633357341, 37422279804.007866]
# 23   [1633637245112, 37856614866.29085]
# 24   [1633640840563, 37254424516.55575]
# 25    [1633644298001, 37072636391.3721]
# 26   [1633647790408, 37124618028.12316]
# 27   [1633651368321, 36549815857.28183]
# 28   [1633654842324, 36198038949.06109]
# 29   [1633658431521, 34700142186.45769]
# 30    [1633662347064, 35206086485.7808]
# 31   [1633666068739, 35138339461.23434]
# 32   [1633669549221, 35010786309.94043]
# 33  [1633673002188, 35032237909.944145]
# 34  [1633676617829, 34272306738.745552]
# 35    [1633680043332, 35708365695.1096]
# 36  [1633683908558, 38316080271.308044]
# 37  [1633687430341, 38144078680.412575]
# 38   [1633691052355, 37985243701.14129]
# 39   [1633695106064, 37536662935.78689]
# 40   [1633698248658, 37444990152.41424]
# 41   [1633702380369, 36988869165.40759]
# 42   [1633705448216, 36336346921.17281]
# 43  [1633708942005, 35682957488.879456]
# 44    [1633712591998, 35291433224.6891]
# 45   [1633716145132, 34920385054.98401]
# 46   [1633720121633, 34813041323.19065]
# 47   [1633723794138, 34776580151.55469]
# 48   [1633727373786, 34452047102.33413]

# %%
import psycopg2
from sqlalchemy import create_engine

engine = create_engine('postgresql://bisasam:1234asdf@datalake.clnjs1yqzw0z.us-east-1.rds.amazonaws.com:5432/datalakebisasam')

engine.execute("SELECT * FROM coin_cata_historical limit 10").fetchall()
# Out:
# []
